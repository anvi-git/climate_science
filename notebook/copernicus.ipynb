# %%
import cdsapi

dataset = "sis-energy-derived-projections"
request = {
    "variable": ["total_precipitation"],
    "spatial_aggregation": "original_grid",
    "energy_product_type": ["capacity_factor_ratio"],
    "temporal_aggregation": "daily",
    "experiment": ["rcp_8_5"],
    "rcm": "regcm4",
    "gcm": ["hadgem2_es"],
    "ensemble_member": ["r1i1p1"]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2026-09-18 14:33:28,896 INFO Request ID is 7edb34c4-6d5d-4605-b882-492ee0a9bfcc
# 2026-09-18 14:33:28,958 INFO status has been updated to accepted
# 2026-09-18 14:33:42,913 INFO status has been updated to running
# 2026-09-18 14:57:54,488 INFO status has been updated to successful
# 490a18f1a8d2afe55e68fbc1c68b9dda.zip:   0%|          | 0.00/6.75G [00:00<?, ?B/s]
# '490a18f1a8d2afe55e68fbc1c68b9dda.zip'
